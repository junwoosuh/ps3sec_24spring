# %% [markdown]
# ## PS3 Discussion: PO Framework in Experiments
#
# # 1. Difference in Means and Potential Outcomes

# %% [markdown]
# We will now come back to the contact-theory field experiment we reviewed last week's section. This research is titled "Building social cohesion between Christians and Muslims through soccer in post-ISIS Iraq" by Salma Mousa.
#
# While we looked at the argument of the paper and main findings last week, we will look at the actual data and eventually re-calculate the research's findings.
#
# If you were to conduct your own research, today's exercise would be the step you would need to take after your study has been conducted (ex. survey responses collected), data has been gathered, and cleaned.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 1.1. Load data

# %%
# Let's load the data by running the following code chunk.
contact <- readRDS("Data/mousa/contact.RData")

head(contact) # let's look at top several rows
# Out:
#   team    league  treated edu church income status1 marital isis_abuse
# 1 team_1  league1 1       6   6      0      2       1       0
# 2 team_2  league1 0       2   5      0      1       0       0
# 3 team_5  league1 1       6   2      4      0       1       0
# 4 team_6  league2 1       6   2      1      1       0       1
# 5 team_9  league1 0       2   2      0      0       0       0
# 6 team_10 league2 1       2   2      2      0       0       0
#   player_type ... suff_sh_t0 suff_sa_t0 nbr_sunni_arab_t0 cash_muslim_t0 attend
# 1 Coach       ... 0          0          0                 0              0
# 2 Coach       ... 0          0          0                 0              1
# 3 Coach       ... 0          0          0                 0              0
# 4 Coach       ... 0          0          0                 0              0
# 5 Coach       ... 0          0          0                 1              0
# ...

# %% [markdown]
# By the way, what we are doing is called a "Replication" of the study's main findings--which is a practice in academia to enhance the transparency of research. It is common practice for researchers to make their raw data available along with the code they used to analyze, so that others can verify the results or those who are interested can build on the project)

# %% [markdown]
# Research design: Researchers contacted existing amateur soccer teams in two northern Iraqi cities comprised of Christian members to partake in a community building program by admitting a few additional soccer players among the local displaced persons to their team. In this process, a total of 28 teams participated, with 14 teams receiving additional players who were Muslim, and the remaining 14 teams receiving additional playesr who were Christian.
#
# 1. Independent Variable (cause / X):
#
# `treated` = Whether individual was assigned to a mixed-member team
# - 1 = Teams that have received three additional players who were Muslim
# - 0 = Teams that have received three additional players who were Christian
#
#
# .
#
# 2. Dependent Variables (effect / outcome variables / Y):
#
# The following are behavioral measures--the researchers followed up with the participants 6 months after the study to assess whether the subjects' behavior varied between the treatment groups.
#
# `train_t1` =  Training with Muslims 6 months post-intervention (train_t1)*
# - 0 = yes
# - 1 = no
#
# `voted_muslim_extra` = Voted for Muslim added player to receive sportsmanship award
#
# - 0 = voted for added Muslim player
# - 1 = voted for added Christian player
# - NA = did not vote
#
# `own_group_preference` = Registered for a mixed team next season
# - 0 = prefer being on a team with one’s own community
# - 1 = “would not mind” or “prefer” being on a mixed team next season
#
#
# The paper can be found at: https://www.science.org/doi/10.1126/science.abb3153

# %% [markdown]
# ### 1.2.Knowledge Check:
# #### 1.2.1. What's the causal argument here?

# %% [markdown]
# (write your response below--to edit a code/text chunk, double click it)
#
# Remember, a causal argument has two structures, a cause and an effect, and there is a directionality. Cause leads to effect.

# %% [markdown]
# The argument of the article is:

# %% [markdown]
# #### 1.2.2. What are the potential outcomes? What is the unit of analysis?

# %% [markdown]
# Potential outcomes:
#
# Unit of analysis:

# %% [markdown]
# ### 1.3. Calculate Difference in Means

# %% [markdown]
# #### 1.3.1. Calculate Difference in Means

# %% [markdown]
# Calculate the average percent of subjects that trained with Muslim community members incidated by `train_t1`==1 among the treatment and control groups, and find the difference.

# %% [markdown]
# Let's do it using the `difference_in_means()` command/function.
# Remember, unlike the simple `mean()`, the  `difference_in_means()` function is not included in the standard R package--you need to "install" and "load" the package in order to use the function. If the below code does not run, it should be installed first using `install.packages("estimatr")` command, then loaded using `library()` command.

# %%
#install.packages("estimatr")
library(estimatr)
difference_in_means()
# Out:
# Error in eval_tidy(formula): 기본값이 없는 인수 "formula"가 누락되어 있습니다
# Traceback:
#
# 1. difference_in_means()
# 2. all.vars(f_rhs(eval_tidy(formula)))
# 3. f_rhs(eval_tidy(formula))
# 4. is_quosure(f)
# 5. eval_tidy(formula)

# %% [markdown]
# ### 1.4 Advanced question / Review: if this was an observational study
#
# This study was an experiment. But how would the study have been if there was no random assignment? If the researcher sampled already-existing mixed teams and non-mixed teams, meaning that team membership were not randomly assigned, how might the result differ? What is a potential confounding factor?

# %% [markdown]
# ### 1.5. Bonus: indexing a dataframe

# %% [markdown]
# The raw data often has many columns--more than you want and need! If you want to just look at a few variables, say, your treatment and outcome variables, you can do so by "indexing".
#
# To index rows and columns, add brackets next to your dataframe object: `contact[]`, and input two vectors: `contact[row index, column index]` one for rows, the other for columns.

# %%
contact[c(1:10),c("treated","own_group_preference","voted_muslim_extra","train_t1")]

#can you tell which is the row index, and which is the column index?
# Out:
#    treated own_group_preference voted_muslim_extra train_t1
# 1  1       0                     1                 1
# 2  0       1                    NA                 0
# 3  1       1                     1                 1
# 4  1       1                     1                 1
# 5  0       1                     0                 0
# 6  1       0                     1                 0
# 7  0       1                     0                 0
# 8  0       0                     0                 1
# 9  0       0                     0                 0
# 10 0       1                     0                 0

# %% [markdown]
# # 2. Practice

# %% [markdown]
# The second example draws data from the hypothetical candidate choice experiment (also called 'conjoint' experiment) where you chose preferred candidates based on their profile characteristics.
#
# Note that the profiles were all generated randomly. For instance, `Gender` of a candidate profile was randomly assigned to be `Male` for approximately a half of the profiles, and `Female` for the other half. This means that the profile contents were randomly assigned--it's an experiment!

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Example of Randomly-generated Candidate Profiles

# %%
survey <- readRDS("survey.RData")
head(survey)
# Out:
#   ResponseId        taskNum choiceNum selected Priority                  Gender
# 1 R_120oto31D0ZIBdn 1       1         0        Green Energy Transition   Female
# 2 R_5OwuzXBOTpeOKCG 1       1         0        Inter-regional inequality Female
# 3 R_1sciFOFzYSVOvhD 1       1         1        Lower-income class        Male
# 4 R_5kWkOswSRKGUpA5 1       1         1        Inter-regional inequality Female
# 5 R_7qhVi1HkSjsMxvr 1       1         1        Lower-income class        Male
# 6 R_6PWWbi85PzYIvPh 1       1         0        Universal Welfare         Female
#   ElectedOffices          PreviousProfession  info Q9     Q2_4 Q2_5 Q2_6 Q2_7
# 1 No Previous Office      Entrepreneur        1    7am63b 2    3    6    4
# 2 House Rep (second term) Entrepreneur        0    edgn2x 2    1    3    5
# 3 House Rep (second term) Government Official 2    fj9qo3 1    2    6    3
# 4 No Previous Office      Entrepreneur        0    5t6hyi 5    6    2    4
# ...

# %% [markdown]
# While you are welcome to study further, for now, just focus on one variable that you are interested in studying, which are your 'treatment' variables. For example, the column `Gender` has a value of `Female` if the randomized candidate choice profile said "Female", and `Male` if the profile said male. `Selected`=1 means the survey respondent chose that candidate as the preferred candidate, 0 means the profile was not selected.

# %%
#First, use the Table command to see how many policy options were there.
table(survey$Priority) 
table(survey$Gender)
table(survey$PreviousProfession)
# Out:
#         Universal Welfare    Develop Suburban Areas   Green Energy Transition
#                       144                       152                       149
# Inter-regional inequality        Lower-income class
#                       159                       152
# Female   Male
#    375    381
#        Entrepreneur Government Official              Lawyer
#                 257                 263                 236

# %% [markdown]
# These are all treatment variables! Pick one that most interests you, and if a variable has more than two options, pick two options (ex. compare the average of "Universal Welfare" versus "Develop Suburban Areas".) and calculate their mean difference.

# %%
# calculate your mean

# %% [markdown]
# Bonus: One way of simplifying the mean of the subset is by adding a conditional statement to the `mean()` function as a second argument. You need to use the pipe symbol `|` or shift+backslash. It's usually located next to `[` `]` on the keyboard.

# %%
mean(survey$selected|survey$Priority=="Universal Welfare")
mean(survey$selected|survey$Priority=="Develop Suburban Areas")
# Out:
# [1] 0.5873016
# [1] 0.6455026

# %% [markdown]
# Bonus 2: Another way of calculating means all at once, is :

# %%
install.packages("FSA") #run this line this if you are running the session for the first time
library(FSA)
# Out:
# Warning message:
# "dependencies 'MASS', 'pbkrtest', 'lattice' are not available"also installing the dependencies 'RcppEigen', 'lme4', 'car'

# %%
Sum <- Summarize(selected ~ Priority,
                data=survey)
Sum
# Out:
# Error in library(FSA): there is no package called 'FSA'
# Traceback:
#
# 1. library(FSA)

# %% [markdown]
# #### 1.3.2. Plot

# %%
suppressMessages(install.packages("ggplot2"))  #run this line this if you are running the session for the first time
library(ggplot2)
library(dplyr)
# Out:
# Warning message:
# "dependency 'MASS' is not available"
#   There are binary versions available but the source versions are later:
#           binary source needs_compilation
# cli        2.5.0  3.6.2              TRUE
# gtable     0.3.0  0.3.4             FALSE
# lifecycle  1.0.0  1.0.4             FALSE
# rlang     0.4.11  1.1.3              TRUE
# scales     1.1.1  1.3.0              TRUE
# vctrs      0.3.8  0.6.5              TRUE
# ggplot2    3.3.3  3.4.4             FALSE
#
#   Binaries will be installed
# package 'cli' successfully unpacked and MD5 sums checked
# package 'rlang' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'rlang'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "C:\Users\james\anaconda3\Lib\R\library\00LOCK\rlang\libs\x64\rlang.dll를 C:\Users\james\anaconda3\Lib\R\library\rlang\libs\x64\rlang.dll로 복사하는데 문제가 발생했습니다: Permission denied"Warning message:
# "restored 'rlang'"
# ...

# %%
Sum = Summarize(selected ~ Priority + info,
                data=survey)  #creates a convenient dataframe of conditional means
Sum$se = Sum$sd / sqrt(Sum$n)

ate1 <- Sum %>% # The data frame to use.
  ggplot(              
    aes(x= Priority, y= mean)) + #specify which variables to use
  geom_point(size  = 2,  #add a geom_point plot, which plots "points"
    position = position_dodge(0.35)) +  #position of the plots
  geom_errorbar(aes(ymin  = mean - 1.96*se, #add a plot of "error bars" , where ymin is the lower bound, ymax is upper bound.
                    ymax  = mean + 1.96*se),
                width = 0.3,
                size  = 1,
                position = position_dodge2(preserve = "single")) +
  theme_bw() + #other options on title, lables, color of bar, size of line etc. 
         theme(legend.position=c(0.85,0.84),axis.title = element_text(face = "bold",size=14),plot.title=element_text(hjust=0.5,face="bold", size=16),
               plot.caption=element_text(hjust=1,size=13,face="italic")) +  ylab("Ratio of Profiles Selected") +
         xlab("Policy Priority of Candidate") +
         labs(caption="Note: Dots indicate average rate of candidate featuring the policy priority being selected, \n bars indicate 95% confidence level.", 
              title="Candidate Selection") +
         theme(text = element_text(family = "serif"))
       
ate1
